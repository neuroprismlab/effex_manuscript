# %% [markdown]
# # Creating plots for the results manuscript
# ### Using functions from plot_results.R script
# Authors: Hallee Shearer and Stephanie Noble

# %%
# source plot_results.R library
scripts_dir <- dirname(rstudioapi::getActiveDocumentContext()$path) # in same dir
source(paste0(scripts_dir,"/plot_results.R"))

# %%
# set params
estimate = 'd' # only works for d currently, need to fix calculate_effex/effect_size/scripts/checker.R to work for r_sq
pooling_methods = c('none', 'net')
motion_method_t = "threshold" # motion method for one-sample t-tests # NOTE: "threshold" refers to 0.1mm threshold, use "threshold2" for 0.2mm threshold
motion_method_not_t = "regression" # motion method for other tests
get_data_from_OSF <- FALSE
save_plots = TRUE # whether to save the plots

# setup dirs - can also define both directly
base_dir <- list.files('/Users', pattern = '^ste.*', full.names = TRUE, all.files = TRUE)
base_dir <- paste0(base_dir,'/Library/CloudStorage/GoogleDrive-s.noble@northeastern.edu/My Drive/Lab/Tasks-Ongoing/-K99/Effect_Size/')
if (!get_data_from_OSF) {
  data_dir <- paste0(base_dir, 'scripts/BrainEffeX_utils/inst/meta/v.RData') # user-specified - only needed if not 
}

# %%
# load data
if (get_data_from_OSF) {
  library(osfr)
  analysis_plan <- osf_retrieve_file("g84tk") %>% osf_download()
  data_path <- "braineffex_data_09-24-25.RData"
  load(data_path)
} else {
  load(data_dir)
}

# %%
# generate plots
for (pooling_method in pooling_methods) {
  print(paste0('Doing pooling method: ', pooling_method))
  combo_name <- paste0('pooling.', pooling_method, '.motion.',motion_method_not_t)
  output_basedir <- paste0(base_dir, 'manuscript/figures/plots/results/curve_fit/',combo_name,'/')  # user-defined path to save the plots
  plot_results(estimate, output_basedir, v, motion_method_t, motion_method_not_t, save_plots)
}
# Out:
# [1] "plotting for pooling method: none"
# [1] "Creating output directory: results/pooling.none/"
# [1] "using motion method regression for study 1: abcd_fc_r_rest_age_months"
# [1] "using motion method regression for study 2: abcd_fc_r_rest_bmi"
# [1] "using motion method regression for study 3: abcd_fc_r_rest_cbcl_scr_syn_aggressive_t_fu1"
# [1] "using motion method regression for study 4: abcd_fc_r_rest_cbcl_scr_syn_aggressive_t"
# [1] "using motion method regression for study 5: abcd_fc_r_rest_cbcl_scr_syn_anxdep_t_fu1"
# [1] "using motion method regression for study 6: abcd_fc_r_rest_cbcl_scr_syn_attention_t_fu1"
# [1] "using motion method regression for study 7: abcd_fc_r_rest_cbcl_scr_syn_attention_t"
# [1] "using motion method regression for study 8: abcd_fc_r_rest_cbcl_scr_syn_external_t_fu1"
# [1] "using motion method regression for study 9: abcd_fc_r_rest_cbcl_scr_syn_external_t"
# [1] "using motion method regression for study 10: abcd_fc_r_rest_cbcl_scr_syn_internal_t_fu1"
# [1] "using motion method regression for study 11: abcd_fc_r_rest_cbcl_scr_syn_internal_t"
# [1] "using motion method regression for study 12: abcd_fc_r_rest_cbcl_scr_syn_rulebreak_t_fu1"
# [1] "using motion method regression for study 13: abcd_fc_r_rest_cbcl_scr_syn_rulebreak_t"
# [1] "using motion method regression for study 14: abcd_fc_r_rest_cbcl_scr_syn_social_t_fu1"
# [1] "using motion method regression for study 15: abcd_fc_r_rest_cbcl_scr_syn_somatic_t_fu1"
# [1] "using motion method regression for study 16: abcd_fc_r_rest_cbcl_scr_syn_thought_t_fu1"
# [1] "using motion method regression for study 17: abcd_fc_r_rest_cbcl_scr_syn_thought_t"
# [1] "using motion method regression for study 18: abcd_fc_r_rest_cbcl_scr_syn_withdep_t_fu1"
# [1] "using motion method regression for study 19: abcd_fc_r_rest_nihtbx_fluidcomp_fc"
# [1] "using motion method regression for study 20: abcd_fc_r_rest_pea_wiscv_tss"
# [1] "using motion method threshold2 for study 21: abcd_fc_t_rest_mid"
# [1] "using motion method threshold2 for study 22: abcd_fc_t_rest_nback"
# [1] "using motion method threshold2 for study 23: abcd_fc_t_rest_sst"
# [1] "using motion method regression for study 24: abcd_fc_t2_rest_sex"
# [1] "using motion method regression for study 25: hbn_fc_r_rest_nih_card"
# [1] "using motion method regression for study 26: hbn_fc_r_rest_nih_flanker"
# [1] "using motion method regression for study 27: hbn_fc_r_rest_nih_list"
# [1] "using motion method regression for study 28: hbn_fc_r_rest_nih_process"
# [1] "using motion method regression for study 29: hbn_fc_r_rest_srs_srs"
# [1] "using motion method regression for study 30: hbn_fc_t2_rest_diag_diag"
# [1] "using motion method threshold2 for study 31: hcp_act_t_emotion"
# [1] "using motion method threshold2 for study 32: hcp_act_t_gambling"
# [1] "using motion method threshold2 for study 33: hcp_act_t_relational"
# [1] "using motion method threshold2 for study 34: hcp_act_t_social"
# [1] "using motion method threshold2 for study 35: hcp_act_t_wm"
# [1] "using motion method regression for study 36: hcp_fc_r_rest_pmat24_a_cr"
# [1] "using motion method regression for study 37: hcp_fc_r_rest_procspeed_ageadj"
# [1] "using motion method threshold2 for study 38: hcp_fc_t_rest_emotion"
# [1] "using motion method threshold2 for study 39: hcp_fc_t_rest_gambling"
# [1] "using motion method threshold2 for study 40: hcp_fc_t_rest_relational"
# [1] "using motion method threshold2 for study 41: hcp_fc_t_rest_social"
# [1] "using motion method threshold2 for study 42: hcp_fc_t_rest_wm"
# [1] "using motion method regression for study 43: hcp_fc_t2_rest_gender"
# [1] "using motion method regression for study 44: pnc_fc_r_rest_add011"
# [1] "using motion method regression for study 45: pnc_fc_r_rest_dep001"
# [1] "using motion method regression for study 46: pnc_fc_r_rest_eat001"
# [1] "using motion method regression for study 47: pnc_fc_r_rest_gad001"
# [1] "using motion method regression for study 48: pnc_fc_r_rest_man001"
# [1] "using motion method regression for study 49: pnc_fc_r_rest_ocd018"
# [1] "using motion method regression for study 50: pnc_fc_r_rest_pan001"
# [1] "using motion method regression for study 51: pnc_fc_r_rest_psy001"
# [1] "using motion method regression for study 52: pnc_fc_r_rest_sip003"
# [1] "using motion method regression for study 53: pnc_fc_t2_rest_sex"
# [1] "using motion method regression for study 54: slim_fc_r_rest_state_anxiety"
# [1] "using motion method regression for study 55: slim_fc_t2_rest_sex"
# [1] "using motion method regression for study 56: ukb_fc_r_rest_age"
# [1] "using motion method regression for study 57: ukb_fc_r_rest_fluid_intelligence"
# [1] "using motion method regression for study 58: ukb_fc_t2_rest_gender"
# [1] "Processing meta-analysis 1 of 10: age (demographic)_reference_shen_268"
# [1] "Processing meta-analysis 2 of 10: age (demographic)_reference_ukb_55"
# [1] "Processing meta-analysis 3 of 10: biometric_reference_shen_268"
# [1] "Processing meta-analysis 4 of 10: psychiatric_reference_shen_268"
# [1] "Processing meta-analysis 5 of 10: cognitive_reference_shen_268"
# [1] "Processing meta-analysis 6 of 10: cognitive_reference_ukb_55"
# [1] "Processing meta-analysis 7 of 10: cognitive (task)_reference_shen_268"
# [1] "Processing meta-analysis 8 of 10: cognitive (task)_reference_voxel"
# [1] "Processing meta-analysis 9 of 10: sex (demographic)_reference_shen_268"
# [1] "Processing meta-analysis 10 of 10: sex (demographic)_reference_ukb_55"
# [1] "using motion method regression for study 1: age (demographic)_reference_shen_268"
# [1] "using motion method regression for study 2: age (demographic)_reference_ukb_55"
# [1] "using motion method regression for study 3: biometric_reference_shen_268"
# [1] "using motion method regression for study 4: psychiatric_reference_shen_268"
# [1] "using motion method regression for study 5: cognitive_reference_shen_268"
# [1] "using motion method regression for study 6: cognitive_reference_ukb_55"
# [1] "using motion method threshold for study 7: cognitive (task)_reference_shen_268"
# [1] "using motion method threshold for study 8: cognitive (task)_reference_voxel"
# [1] "using motion method regression for study 9: sex (demographic)_reference_shen_268"
# [1] "using motion method regression for study 10: sex (demographic)_reference_ukb_55"
# [1] "Fitting lines for point and conservative estimates"
# [1] "Fitting lines for Point Estimates"
# [1] "Fitting lines for Conservative Estimates"
# [1] "Fitting lines for large N studies only"
# [1] "Fitting lines for Point Estimates (n > 900)"
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# [1] "Fitting lines for multivariate effect sizes"
# [1] "Fitting lines for Multivariate Effect Sizes"
# [1] "plotting for pooling method: net"
# [1] "Creating output directory: results/pooling.net/"
# [1] "using motion method regression for study 1: abcd_fc_r_rest_age_months"
# [1] "using motion method regression for study 2: abcd_fc_r_rest_bmi"
# [1] "using motion method regression for study 3: abcd_fc_r_rest_cbcl_scr_syn_aggressive_t_fu1"
# [1] "using motion method regression for study 4: abcd_fc_r_rest_cbcl_scr_syn_aggressive_t"
# [1] "using motion method regression for study 5: abcd_fc_r_rest_cbcl_scr_syn_anxdep_t_fu1"
# [1] "using motion method regression for study 6: abcd_fc_r_rest_cbcl_scr_syn_attention_t_fu1"
# [1] "using motion method regression for study 7: abcd_fc_r_rest_cbcl_scr_syn_attention_t"
# [1] "using motion method regression for study 8: abcd_fc_r_rest_cbcl_scr_syn_external_t_fu1"
# [1] "using motion method regression for study 9: abcd_fc_r_rest_cbcl_scr_syn_external_t"
# [1] "using motion method regression for study 10: abcd_fc_r_rest_cbcl_scr_syn_internal_t_fu1"
# [1] "using motion method regression for study 11: abcd_fc_r_rest_cbcl_scr_syn_internal_t"
# [1] "using motion method regression for study 12: abcd_fc_r_rest_cbcl_scr_syn_rulebreak_t_fu1"
# [1] "using motion method regression for study 13: abcd_fc_r_rest_cbcl_scr_syn_rulebreak_t"
# [1] "using motion method regression for study 14: abcd_fc_r_rest_cbcl_scr_syn_social_t_fu1"
# [1] "using motion method regression for study 15: abcd_fc_r_rest_cbcl_scr_syn_somatic_t_fu1"
# [1] "using motion method regression for study 16: abcd_fc_r_rest_cbcl_scr_syn_thought_t_fu1"
# [1] "using motion method regression for study 17: abcd_fc_r_rest_cbcl_scr_syn_thought_t"
# [1] "using motion method regression for study 18: abcd_fc_r_rest_cbcl_scr_syn_withdep_t_fu1"
# [1] "using motion method regression for study 19: abcd_fc_r_rest_nihtbx_fluidcomp_fc"
# [1] "using motion method regression for study 20: abcd_fc_r_rest_pea_wiscv_tss"
# [1] "using motion method threshold2 for study 21: abcd_fc_t_rest_mid"
# [1] "using motion method threshold2 for study 22: abcd_fc_t_rest_nback"
# [1] "using motion method threshold2 for study 23: abcd_fc_t_rest_sst"
# [1] "using motion method regression for study 24: abcd_fc_t2_rest_sex"
# [1] "using motion method regression for study 25: hbn_fc_r_rest_nih_card"
# [1] "using motion method regression for study 26: hbn_fc_r_rest_nih_flanker"
# [1] "using motion method regression for study 27: hbn_fc_r_rest_nih_list"
# [1] "using motion method regression for study 28: hbn_fc_r_rest_nih_process"
# [1] "using motion method regression for study 29: hbn_fc_r_rest_srs_srs"
# [1] "using motion method regression for study 30: hbn_fc_t2_rest_diag_diag"
# [1] "using motion method threshold2 for study 31: hcp_act_t_emotion"
# [1] "using motion method threshold2 for study 32: hcp_act_t_gambling"
# [1] "using motion method threshold2 for study 33: hcp_act_t_relational"
# [1] "using motion method threshold2 for study 34: hcp_act_t_social"
# [1] "using motion method threshold2 for study 35: hcp_act_t_wm"
# [1] "using motion method regression for study 36: hcp_fc_r_rest_pmat24_a_cr"
# [1] "using motion method regression for study 37: hcp_fc_r_rest_procspeed_ageadj"
# [1] "using motion method threshold2 for study 38: hcp_fc_t_rest_emotion"
# [1] "using motion method threshold2 for study 39: hcp_fc_t_rest_gambling"
# [1] "using motion method threshold2 for study 40: hcp_fc_t_rest_relational"
# [1] "using motion method threshold2 for study 41: hcp_fc_t_rest_social"
# [1] "using motion method threshold2 for study 42: hcp_fc_t_rest_wm"
# [1] "using motion method regression for study 43: hcp_fc_t2_rest_gender"
# [1] "using motion method regression for study 44: pnc_fc_r_rest_add011"
# [1] "using motion method regression for study 45: pnc_fc_r_rest_dep001"
# [1] "using motion method regression for study 46: pnc_fc_r_rest_eat001"
# [1] "using motion method regression for study 47: pnc_fc_r_rest_gad001"
# [1] "using motion method regression for study 48: pnc_fc_r_rest_man001"
# [1] "using motion method regression for study 49: pnc_fc_r_rest_ocd018"
# [1] "using motion method regression for study 50: pnc_fc_r_rest_pan001"
# [1] "using motion method regression for study 51: pnc_fc_r_rest_psy001"
# [1] "using motion method regression for study 52: pnc_fc_r_rest_sip003"
# [1] "using motion method regression for study 53: pnc_fc_t2_rest_sex"
# [1] "using motion method regression for study 54: slim_fc_r_rest_state_anxiety"
# [1] "using motion method regression for study 55: slim_fc_t2_rest_sex"
# [1] "using motion method regression for study 56: ukb_fc_r_rest_age"
# [1] "using motion method regression for study 57: ukb_fc_r_rest_fluid_intelligence"
# [1] "using motion method regression for study 58: ukb_fc_t2_rest_gender"
# [1] "Processing meta-analysis 1 of 10: age (demographic)_reference_shen_268"
# [1] "Processing meta-analysis 2 of 10: age (demographic)_reference_ukb_55"
# [1] "Processing meta-analysis 3 of 10: biometric_reference_shen_268"
# [1] "Processing meta-analysis 4 of 10: psychiatric_reference_shen_268"
# [1] "Processing meta-analysis 5 of 10: cognitive_reference_shen_268"
# [1] "Processing meta-analysis 6 of 10: cognitive_reference_ukb_55"
# [1] "Processing meta-analysis 7 of 10: cognitive (task)_reference_shen_268"
# [1] "Processing meta-analysis 8 of 10: cognitive (task)_reference_voxel"
# [1] "Processing meta-analysis 9 of 10: sex (demographic)_reference_shen_268"
# [1] "Processing meta-analysis 10 of 10: sex (demographic)_reference_ukb_55"
# [1] "using motion method regression for study 1: age (demographic)_reference_shen_268"
# [1] "using motion method regression for study 2: age (demographic)_reference_ukb_55"
# [1] "using motion method regression for study 3: biometric_reference_shen_268"
# [1] "using motion method regression for study 4: psychiatric_reference_shen_268"
# [1] "using motion method regression for study 5: cognitive_reference_shen_268"
# [1] "using motion method regression for study 6: cognitive_reference_ukb_55"
# [1] "using motion method threshold for study 7: cognitive (task)_reference_shen_268"
# [1] "using motion method threshold for study 8: cognitive (task)_reference_voxel"
# [1] "using motion method regression for study 9: sex (demographic)_reference_shen_268"
# [1] "using motion method regression for study 10: sex (demographic)_reference_ukb_55"
# [1] "Fitting lines for point and conservative estimates"
# [1] "Fitting lines for Point Estimates"
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# [1] "Fitting lines for Conservative Estimates"
# [1] "Fitting lines for large N studies only"
# [1] "Fitting lines for Point Estimates (n > 900)"
# [1] "Fitting lines for multivariate effect sizes"
# [1] "Fitting lines for Multivariate Effect Sizes"
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# There were 50 or more warnings (use warnings() to see the first 50)
